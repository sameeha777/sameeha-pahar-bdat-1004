# %%
Let's go through the execution of the statements step by step:

1. The module is imported, and the variable `a` is initialized with the value 0.

2. The function `b()` is called for the first time:
   - The `global` keyword is used to indicate that the variable `a` inside the function refers to the global variable `a` defined in the module.
   - The function `c()` is called with the current value of `a` (which is 0).
   - Inside the function `c()`, the value of `a` (0) is incremented by 2, resulting in 2.
   - The modified value of `a` (2) is assigned back to the global variable `a`.

3. The function `b()` is called for the second time:
   - The `global` keyword is used again to indicate that the variable `a` inside the function refers to the global variable `a`.
   - The function `c()` is called with the current value of `a` (which is 2).
   - Inside the function `c()`, the value of `a` (2) is incremented by 2, resulting in 4.
   - The modified value of `a` (4) is assigned back to the global variable `a`.

4. The function `b()` is called for the third time:
   - The `global` keyword is used again to indicate that the variable `a` inside the function refers to the global variable `a`.
   - The function `c()` is called with the current value of `a` (which is 4).
   - Inside the function `c()`, the value of `a` (4) is incremented by 2, resulting in 6.
   - The modified value of `a` (6) is assigned back to the global variable `a`.

5. Finally, the last expression `a` is evaluated:
   - At this point, the global variable `a` has the value 6, which was the result of the last call to the function `b()`.
   - Therefore, when the last expression `a` is evaluated, the value displayed will be 6.

To summarize, the value displayed when the last expression `a` is evaluated is 6. The function `b()` is called three times, and each time it updates the global variable `a` by calling the function `c()` to increment its value by 2.
# Out:
#   Cell In[1], line 1
#     Let's go through the execution of the statements step by step:
#        ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
def fileLength(filename):
    try:
        infile = open(filename)
        content = infile.read()
        infile.close()
        length = len(content)
        return length
    except FileNotFoundError:
        print("File", filename, "not found.")
>>> fileLength('midterm.py')
358
>>> fileLength('idterm.py')
File idterm.py not found.
# Out:
#   Cell In[2], line 10
#     >>> fileLength('midterm.py')
#     ^
# SyntaxError: invalid syntax

# %%
class Marsupial:
    def __init__(self):
        self.pouch = []

    def put_in_pouch(self, item):
        self.pouch.append(item)

    def pouch_contents(self):
        return self.pouch


class Kangaroo(Marsupial):
    def __init__(self, x, y):
        super().__init__()
        self.x = x
        self.y = y

    def jump(self, dx, dy):
        self.x += dx
        self.y += dy

    def __str__(self):
        return f"I am a Kangaroo located at coordinates ({self.x},{self.y})"
    k = Kangaroo(0, 0)
print(k)  # Output: I am a Kangaroo located at coordinates (0,0)

k.put_in_pouch('doll')
k.put_in_pouch('firetruck')
k.put_in_pouch('kitten')
print(k.pouch_contents())  # Output: ['doll', 'firetruck', 'kitten']

k.jump(1, 0)
k.jump(1, 0)
k.jump(1, 0)
print(k)  # Output: I am a Kangaroo located at coordinates (3,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 25
#      23         return f"I am a Kangaroo located at coordinates ({self.x},{self.y})"
#      24     k = Kangaroo(0, 0)
# ---> 25 print(k)  # Output: I am a Kangaroo located at coordinates (0,0)
#      27 k.put_in_pouch('doll')
#      28 k.put_in_pouch('firetruck')
#
# NameError: name 'k' is not defined

# %%
def collatz(x):
    print(x)
    if x == 1:
        return
    elif x % 2 == 0:
        collatz(x // 2)
    else:
        collatz(3 * x + 1)
        collatz(1)
1
collatz(10)
10
5
16
8
4
2
1
# Out:
# 10
# 5
# 16
# 8
# 4
# 2
# 1
# 1
# 1

# %%
from html.parser import HTMLParser


class HeadingParser(HTMLParser):
    def __init__(self):
        super().__init__()
        self.indentation = 0
        self.headings = []

    def handle_starttag(self, tag, attrs):
        if tag.startswith('h'):
            self.indentation = int(tag[1:]) - 1

    def handle_endtag(self, tag):
        if tag.startswith('h'):
            self.indentation = 0

    def handle_data(self, data):
        if self.indentation > 0:
            heading = ' ' * self.indentation + data.strip()
            self.headings.append(heading)

    def print_headings(self):
        for heading in self.headings:
            print(heading)


# Usage example
infile = open('w3c.html')
content = infile.read()
infile.close()

hp = HeadingParser()
hp.feed(content)
hp.print_headings()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 29
#      25             print(heading)
#      28 # Usage example
# ---> 29 infile = open('w3c.html')
#      30 content = infile.read()
#      31 infile.close()
#
# File ~\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:282, in _modified_open(file, *args, **kwargs)
#     275 if file in {0, 1, 2}:
#     276     raise ValueError(
#     277         f"IPython won't let you open fd={file} by default "
#     278         "as it is likely to crash IPython. If you know what you are doing, "
#     279         "you can use builtins' open."
#     280     )
# --> 282 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'w3c.html'

# %%
import requests
from bs4 import BeautifulSoup

def webdir(url, depth, indent):
    if depth < 0:
        return

    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')

    print(' ' * indent + url)

    if depth == 0:
        return

    for link in soup.find_all('a'):
        href = link.get('href')
        if href.startswith('http'):
            webdir(href, depth - 1, indent + 4)
            webdir('http://reed.cs.depaul.edu/lperkovic/csc242/test1.html', 2, 0
# Out:
#   Cell In[10], line 21
#
#     ^
# SyntaxError: incomplete input

# %%
upper_words = [word.upper() for word in words]
lower_words = [word.lower() for word in words]
word_lengths = [len(word) for word in words]
word_info ==[[word.long_words = [word for word in words if len(word) >= 4]upper(), word.lower(), len(word)] for word in words]
# Out:
#   Cell In[12], line 4
#     word_info ==[[word.long_words = [word for word in words if len(word) >= 4]upper(), word.lower(), len(word)] for word in words]
#                   ^
# SyntaxError: cannot assign to attribute here. Maybe you meant '==' instead of '='?

# %%
SELECT Temperature
FROM TableName;
SELECT DISTINCT City
FROM TableName;
SELECT *
FROM TableName
WHERE Country = 'India';
SELECT *
FROM TableName
WHERE Season = 'Fall';
